# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import urllib
from scipy.stats import linregress

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\rebec\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\rebec\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import API key
#from api_keys import weather_api_key (it wasn working.. I still need help with hiding the api key!) 
weather_api_key = "f3a7cdb929d73325e29bab1d38832bb8"

# Incorporated citipy to determine city based on latitude and longitude

from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %%
#Perform a weather check on each city using a series of successive API calls.
#Include a print log of each city as it'sbeing processed (with the city number and city name).

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | marawi
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | carnarvon
# Processing Record 6 of Set 1 | lasa
# Processing Record 7 of Set 1 | prieska
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | lazaro cardenas
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | trebaseleghe
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | shingu
# Processing Record 16 of Set 1 | severo-kurilsk
# Processing Record 17 of Set 1 | berlevag
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | half moon bay
# Processing Record 20 of Set 1 | sao filipe
# Processing Record 21 of Set 1 | minatitlan
# Processing Record 22 of Set 1 | robertsport
# Processing Record 23 of Set 1 | nsoko
# Processing Record 24 of Set 1 | palora
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | springdale
# Processing Record 27 of Set 1 | klyuchi
# Processing Record 28 of Set 1 | chokurdakh
# Processing Record 29 of Set 1 | timberlake
# Processing Record 30 of Set 1 | ponta do sol
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | mount gambier
# Processing Record 33 of Set 1 | dillon
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | kenai
# Processing Record 36 of Set 1 | suntar
# Processing Record 37 of Set 1 | palmer
# Processing Record 38 of Set 1 | lata
# Processing Record 39 of Set 1 | zhangye
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | reconquista
# Processing Record 42 of Set 1 | upernavik
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | sobolevo
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | nome
# Processing Record 48 of Set 1 | cidreira
# Processing Record 49 of Set 1 | coihaique
# Processing Record 50 of Set 1 | albany
# Processing Record 0 of Set 2 | saint-philippe
# Processing Record 1 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 2 | srednekolymsk
# Processing Record 3 of Set 2 | darnah
# Processing Record 4 of Set 2 | clyde river
# Processing Record 5 of Set 2 | alice town
# Processing Record 6 of Set 2 | fare
# Processing Record 7 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 2 | ayer itam
# City not found. Skipping...
# Processing Record 9 of Set 2 | motupe
# Processing Record 10 of Set 2 | tiksi
# Processing Record 11 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 12 of Set 2 | yashkul
# Processing Record 13 of Set 2 | narsaq
# Processing Record 14 of Set 2 | tasiilaq
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | nuevo laredo
# Processing Record 18 of Set 2 | bulgan
# Processing Record 19 of Set 2 | cabo san lucas
# Processing Record 20 of Set 2 | victoria
# Processing Record 21 of Set 2 | longyearbyen
# Processing Record 22 of Set 2 | kloulklubed
# Processing Record 23 of Set 2 | makakilo city
# Processing Record 24 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 2 | chuy
# Processing Record 27 of Set 2 | norman wells
# Processing Record 28 of Set 2 | sergeyevka
# Processing Record 29 of Set 2 | harper
# Processing Record 30 of Set 2 | kodiak
# Processing Record 31 of Set 2 | palu
# Processing Record 32 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 33 of Set 2 | lompoc
# Processing Record 34 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 2 | mendi
# Processing Record 36 of Set 2 | hasaki
# Processing Record 37 of Set 2 | bilma
# Processing Record 38 of Set 2 | smidovich
# Processing Record 39 of Set 2 | polson
# Processing Record 40 of Set 2 | pangnirtung
# Processing Record 41 of Set 2 | timisoara
# Processing Record 42 of Set 2 | pitimbu
# Processing Record 43 of Set 2 | skegness
# Processing Record 44 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 2 | ibirama
# Processing Record 46 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 2 | kindu
# Processing Record 48 of Set 2 | ilulissat
# Processing Record 49 of Set 2 | umm jarr
# City not found. Skipping...
# Processing Record 0 of Set 3 | kahului
# Processing Record 1 of Set 3 | kavieng
# Processing Record 2 of Set 3 | namie
# Processing Record 3 of Set 3 | saint-augustin
# Processing Record 4 of Set 3 | ishigaki
# Processing Record 5 of Set 3 | avarua
# Processing Record 6 of Set 3 | pacifica
# Processing Record 7 of Set 3 | gilazi
# City not found. Skipping...
# Processing Record 8 of Set 3 | bathsheba
# Processing Record 9 of Set 3 | farmington
# Processing Record 10 of Set 3 | bantry
# Processing Record 11 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 3 | troitsko-pechorsk
# Processing Record 13 of Set 3 | richards bay
# Processing Record 14 of Set 3 | awbari
# Processing Record 15 of Set 3 | xuddur
# Processing Record 16 of Set 3 | adrar
# Processing Record 17 of Set 3 | yeppoon
# Processing Record 18 of Set 3 | souillac
# Processing Record 19 of Set 3 | east london
# Processing Record 20 of Set 3 | airai
# Processing Record 21 of Set 3 | talnakh
# Processing Record 22 of Set 3 | rawson
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | ostrovnoy
# Processing Record 26 of Set 3 | saquarema
# Processing Record 27 of Set 3 | yulara
# Processing Record 28 of Set 3 | jalu
# Processing Record 29 of Set 3 | meulaboh
# Processing Record 30 of Set 3 | bluff
# Processing Record 31 of Set 3 | wanning
# Processing Record 32 of Set 3 | puerto ayora
# Processing Record 33 of Set 3 | sibolga
# Processing Record 34 of Set 3 | kununurra
# Processing Record 35 of Set 3 | pontianak
# Processing Record 36 of Set 3 | san patricio
# Processing Record 37 of Set 3 | hobart
# Processing Record 38 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 3 | ust-tsilma
# Processing Record 41 of Set 3 | russell
# Processing Record 42 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 3 | luderitz
# Processing Record 44 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 3 | carupano
# Processing Record 46 of Set 3 | kazachinskoye
# Processing Record 47 of Set 3 | saldanha
# Processing Record 48 of Set 3 | mahebourg
# Processing Record 49 of Set 3 | poiana marului
# Processing Record 0 of Set 4 | lalmohan
# Processing Record 1 of Set 4 | nikolskoye
# Processing Record 2 of Set 4 | katsuura
# Processing Record 3 of Set 4 | altay
# Processing Record 4 of Set 4 | lisakovsk
# Processing Record 5 of Set 4 | dongsheng
# Processing Record 6 of Set 4 | ribeira grande
# Processing Record 7 of Set 4 | caravelas
# Processing Record 8 of Set 4 | kapaa
# Processing Record 9 of Set 4 | saskylakh
# Processing Record 10 of Set 4 | port hawkesbury
# Processing Record 11 of Set 4 | khatanga
# Processing Record 12 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 4 | aksarka
# Processing Record 14 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 4 | calabozo
# Processing Record 16 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 4 | faanui
# Processing Record 18 of Set 4 | sinjar
# Processing Record 19 of Set 4 | castro
# Processing Record 20 of Set 4 | isangel
# Processing Record 21 of Set 4 | urbano santos
# Processing Record 22 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 23 of Set 4 | ancud
# Processing Record 24 of Set 4 | tiznit
# Processing Record 25 of Set 4 | jamestown
# Processing Record 26 of Set 4 | whitianga
# Processing Record 27 of Set 4 | agotnes
# Processing Record 28 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 29 of Set 4 | kruisfontein
# Processing Record 30 of Set 4 | lerwick
# Processing Record 31 of Set 4 | catamarca
# Processing Record 32 of Set 4 | arraial do cabo
# Processing Record 33 of Set 4 | puerto carreno
# Processing Record 34 of Set 4 | gondanglegi
# Processing Record 35 of Set 4 | iqaluit
# Processing Record 36 of Set 4 | bengkulu
# Processing Record 37 of Set 4 | codrington
# Processing Record 38 of Set 4 | sorland
# Processing Record 39 of Set 4 | paita
# Processing Record 40 of Set 4 | hami
# Processing Record 41 of Set 4 | bambanglipuro
# Processing Record 42 of Set 4 | acandi
# Processing Record 43 of Set 4 | ilorin
# Processing Record 44 of Set 4 | poum
# Processing Record 45 of Set 4 | namatanai
# Processing Record 46 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 4 | port blair
# Processing Record 48 of Set 4 | lebu
# Processing Record 49 of Set 4 | kanel
# Processing Record 0 of Set 5 | kavaratti
# Processing Record 1 of Set 5 | savinka
# Processing Record 2 of Set 5 | honiara
# Processing Record 3 of Set 5 | najran
# Processing Record 4 of Set 5 | dikson
# Processing Record 5 of Set 5 | saint anthony
# Processing Record 6 of Set 5 | fergus falls
# Processing Record 7 of Set 5 | maniitsoq
# Processing Record 8 of Set 5 | chapais
# Processing Record 9 of Set 5 | saint george
# Processing Record 10 of Set 5 | jaunjelgava
# Processing Record 11 of Set 5 | port elizabeth
# Processing Record 12 of Set 5 | korla
# Processing Record 13 of Set 5 | puqi
# Processing Record 14 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 15 of Set 5 | bambous virieux
# Processing Record 16 of Set 5 | skovde
# City not found. Skipping...
# Processing Record 17 of Set 5 | ondjiva
# Processing Record 18 of Set 5 | batemans bay
# Processing Record 19 of Set 5 | aras
# Processing Record 20 of Set 5 | havre-saint-pierre
# Processing Record 21 of Set 5 | bethel
# Processing Record 22 of Set 5 | ahipara
# Processing Record 23 of Set 5 | puerto madryn
# Processing Record 24 of Set 5 | sakata
# Processing Record 25 of Set 5 | amga
# Processing Record 26 of Set 5 | leningradskiy
# Processing Record 27 of Set 5 | sola
# Processing Record 28 of Set 5 | kaitangata
# Processing Record 29 of Set 5 | ayan
# Processing Record 30 of Set 5 | seoul
# Processing Record 31 of Set 5 | torbay
# Processing Record 32 of Set 5 | wilmington
# Processing Record 33 of Set 5 | matara
# Processing Record 34 of Set 5 | sao miguel do iguacu
# Processing Record 35 of Set 5 | hambantota
# Processing Record 36 of Set 5 | bandarbeyla
# Processing Record 37 of Set 5 | xining
# Processing Record 38 of Set 5 | vostochnyy
# Processing Record 39 of Set 5 | sao lourenco do oeste
# Processing Record 40 of Set 5 | thompson
# Processing Record 41 of Set 5 | asau
# Processing Record 42 of Set 5 | oistins
# Processing Record 43 of Set 5 | bazarnyye mataki
# Processing Record 44 of Set 5 | sao joao da barra
# Processing Record 45 of Set 5 | sokoni
# Processing Record 46 of Set 5 | cherskiy
# Processing Record 47 of Set 5 | arrifes
# Processing Record 48 of Set 5 | horsham
# Processing Record 49 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 0 of Set 6 | myaundzha
# Processing Record 1 of Set 6 | yumen
# Processing Record 2 of Set 6 | alamogordo
# Processing Record 3 of Set 6 | soyo
# Processing Record 4 of Set 6 | tura
# Processing Record 5 of Set 6 | falmouth
# Processing Record 6 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 6 | tapia
# Processing Record 8 of Set 6 | bilibino
# Processing Record 9 of Set 6 | porto novo
# Processing Record 10 of Set 6 | tagusao
# Processing Record 11 of Set 6 | ciudad bolivar
# Processing Record 12 of Set 6 | sakakah
# Processing Record 13 of Set 6 | belmonte
# Processing Record 14 of Set 6 | maceio
# Processing Record 15 of Set 6 | suez
# Processing Record 16 of Set 6 | tual
# Processing Record 17 of Set 6 | saurimo
# Processing Record 18 of Set 6 | madison
# Processing Record 19 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 6 | divo
# Processing Record 21 of Set 6 | caiaponia
# Processing Record 22 of Set 6 | sechura
# Processing Record 23 of Set 6 | manokwari
# Processing Record 24 of Set 6 | hovd
# Processing Record 25 of Set 6 | le port
# Processing Record 26 of Set 6 | san policarpo
# Processing Record 27 of Set 6 | nemuro
# Processing Record 28 of Set 6 | ferndale
# Processing Record 29 of Set 6 | naftah
# City not found. Skipping...
# Processing Record 30 of Set 6 | deep river
# Processing Record 31 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 6 | kure
# Processing Record 33 of Set 6 | pangai
# Processing Record 34 of Set 6 | tandil
# Processing Record 35 of Set 6 | pochutla
# Processing Record 36 of Set 6 | beloha
# Processing Record 37 of Set 6 | provideniya
# Processing Record 38 of Set 6 | guipavas
# Processing Record 39 of Set 6 | georgetown
# Processing Record 40 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 41 of Set 6 | tramandai
# Processing Record 42 of Set 6 | sandnessjoen
# Processing Record 43 of Set 6 | kachug
# Processing Record 44 of Set 6 | ossora
# Processing Record 45 of Set 6 | beringovskiy
# Processing Record 46 of Set 6 | vila velha
# Processing Record 47 of Set 6 | vaitape
# Processing Record 48 of Set 6 | ponta delgada
# Processing Record 49 of Set 6 | mokrous
# Processing Record 0 of Set 7 | tiassale
# Processing Record 1 of Set 7 | kattivakkam
# Processing Record 2 of Set 7 | sur
# Processing Record 3 of Set 7 | san quintin
# Processing Record 4 of Set 7 | bitung
# Processing Record 5 of Set 7 | nampula
# Processing Record 6 of Set 7 | hirara
# Processing Record 7 of Set 7 | lumberton
# Processing Record 8 of Set 7 | macusani
# Processing Record 9 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 7 | luau
# Processing Record 11 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 7 | panzhihua
# Processing Record 13 of Set 7 | comodoro rivadavia
# Processing Record 14 of Set 7 | cherbourg
# Processing Record 15 of Set 7 | menongue
# Processing Record 16 of Set 7 | jambi
# Processing Record 17 of Set 7 | taltal
# Processing Record 18 of Set 7 | ngorongoro
# Processing Record 19 of Set 7 | leo
# Processing Record 20 of Set 7 | goderich
# Processing Record 21 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 7 | xiongshi
# City not found. Skipping...
# Processing Record 23 of Set 7 | axim
# Processing Record 24 of Set 7 | usakos
# Processing Record 25 of Set 7 | yar-sale
# Processing Record 26 of Set 7 | marang
# Processing Record 27 of Set 7 | barnstaple
# Processing Record 28 of Set 7 | vanimo
# Processing Record 29 of Set 7 | rostovka
# Processing Record 30 of Set 7 | moissala
# Processing Record 31 of Set 7 | vila do maio
# Processing Record 32 of Set 7 | babu
# Processing Record 33 of Set 7 | yerbogachen
# Processing Record 34 of Set 7 | olafsvik
# Processing Record 35 of Set 7 | palmares do sul
# Processing Record 36 of Set 7 | kaeo
# Processing Record 37 of Set 7 | guilin
# Processing Record 38 of Set 7 | male
# Processing Record 39 of Set 7 | warkworth
# Processing Record 40 of Set 7 | abatskoye
# Processing Record 41 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 7 | severo-yeniseyskiy
# Processing Record 43 of Set 7 | lavrentiya
# Processing Record 44 of Set 7 | salalah
# Processing Record 45 of Set 7 | guanica
# Processing Record 46 of Set 7 | qesarya
# Processing Record 47 of Set 7 | urumqi
# Processing Record 48 of Set 7 | mwinilunga
# Processing Record 49 of Set 7 | oktyabrskoye
# Processing Record 0 of Set 8 | geraldton
# Processing Record 1 of Set 8 | jamuria
# Processing Record 2 of Set 8 | shetpe
# Processing Record 3 of Set 8 | kalaleh
# Processing Record 4 of Set 8 | bambui
# Processing Record 5 of Set 8 | saint-pierre
# Processing Record 6 of Set 8 | castlerea
# Processing Record 7 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 8 | vestmanna
# Processing Record 9 of Set 8 | boyolangu
# Processing Record 10 of Set 8 | gizo
# Processing Record 11 of Set 8 | inuvik
# Processing Record 12 of Set 8 | tongling
# Processing Record 13 of Set 8 | hirado
# Processing Record 14 of Set 8 | lafiagi
# Processing Record 15 of Set 8 | muros
# Processing Record 16 of Set 8 | flinders
# Processing Record 17 of Set 8 | norfolk
# Processing Record 18 of Set 8 | pevek
# Processing Record 19 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 8 | puerto maldonado
# Processing Record 21 of Set 8 | yenotayevka
# Processing Record 22 of Set 8 | gornyy
# Processing Record 23 of Set 8 | lima
# Processing Record 24 of Set 8 | charlestown
# Processing Record 25 of Set 8 | poindimie
# Processing Record 26 of Set 8 | san carlos de bariloche
# Processing Record 27 of Set 8 | bangolo
# Processing Record 28 of Set 8 | port-gentil
# Processing Record 29 of Set 8 | portland
# Processing Record 30 of Set 8 | atasu
# Processing Record 31 of Set 8 | jasper
# Processing Record 32 of Set 8 | zhigansk
# Processing Record 33 of Set 8 | plettenberg bay
# Processing Record 34 of Set 8 | sitka
# Processing Record 35 of Set 8 | sharjah
# Processing Record 36 of Set 8 | riyadh
# Processing Record 37 of Set 8 | quatre cocos
# Processing Record 38 of Set 8 | tamparan
# Processing Record 39 of Set 8 | acapulco
# Processing Record 40 of Set 8 | namibe
# Processing Record 41 of Set 8 | bela
# Processing Record 42 of Set 8 | saint-louis
# Processing Record 43 of Set 8 | sinnamary
# Processing Record 44 of Set 8 | homer
# Processing Record 45 of Set 8 | guerrero negro
# Processing Record 46 of Set 8 | iskateley
# Processing Record 47 of Set 8 | omboue
# Processing Record 48 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 8 | port hardy
# Processing Record 0 of Set 9 | monrovia
# Processing Record 1 of Set 9 | dwarka
# Processing Record 2 of Set 9 | la serena
# Processing Record 3 of Set 9 | kingsland
# Processing Record 4 of Set 9 | merauke
# Processing Record 5 of Set 9 | palmas
# Processing Record 6 of Set 9 | kaka
# Processing Record 7 of Set 9 | mawlaik
# Processing Record 8 of Set 9 | imbituba
# Processing Record 9 of Set 9 | diapaga
# Processing Record 10 of Set 9 | kirovskiy
# Processing Record 11 of Set 9 | hay river
# Processing Record 12 of Set 9 | shreveport
# Processing Record 13 of Set 9 | alice springs
# Processing Record 14 of Set 9 | la peca
# Processing Record 15 of Set 9 | amancio
# City not found. Skipping...
# Processing Record 16 of Set 9 | mayo
# Processing Record 17 of Set 9 | lappeenranta
# Processing Record 18 of Set 9 | aketi
# Processing Record 19 of Set 9 | camacha
# Processing Record 20 of Set 9 | cayenne
# Processing Record 21 of Set 9 | komsomolskiy
# Processing Record 22 of Set 9 | nishihara
# Processing Record 23 of Set 9 | erenhot
# Processing Record 24 of Set 9 | verkhoyansk
# Processing Record 25 of Set 9 | karpathos
# Processing Record 26 of Set 9 | mlonggo
# Processing Record 27 of Set 9 | sorong
# Processing Record 28 of Set 9 | moose factory
# Processing Record 29 of Set 9 | magdagachi
# Processing Record 30 of Set 9 | daura
# Processing Record 31 of Set 9 | risod
# Processing Record 32 of Set 9 | sayyan
# Processing Record 33 of Set 9 | goundam
# Processing Record 34 of Set 9 | beibei
# Processing Record 35 of Set 9 | udachnyy
# Processing Record 36 of Set 9 | waipawa
# Processing Record 37 of Set 9 | puerto escondido
# Processing Record 38 of Set 9 | salgado
# Processing Record 39 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 40 of Set 9 | finale emilia
# Processing Record 41 of Set 9 | asfi
# Processing Record 42 of Set 9 | gardez
# Processing Record 43 of Set 9 | san cristobal
# Processing Record 44 of Set 9 | ostersund
# Processing Record 45 of Set 9 | port macquarie
# Processing Record 46 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 47 of Set 9 | katobu
# Processing Record 48 of Set 9 | mehamn
# Processing Record 49 of Set 9 | flic en flac
# Processing Record 0 of Set 10 | klaksvik
# Processing Record 1 of Set 10 | butterworth
# Processing Record 2 of Set 10 | ipora
# Processing Record 3 of Set 10 | limoges
# Processing Record 4 of Set 10 | batagay
# Processing Record 5 of Set 10 | lorengau
# Processing Record 6 of Set 10 | denpasar
# Processing Record 7 of Set 10 | lewisporte
# Processing Record 8 of Set 10 | borogontsy
# Processing Record 9 of Set 10 | horta
# Processing Record 10 of Set 10 | tazmalt
# Processing Record 11 of Set 10 | necochea
# Processing Record 12 of Set 10 | santiago del estero
# Processing Record 13 of Set 10 | praia da vitoria
# Processing Record 14 of Set 10 | pisco
# Processing Record 15 of Set 10 | kamaishi
# Processing Record 16 of Set 10 | baykit
# Processing Record 17 of Set 10 | campobasso
# Processing Record 18 of Set 10 | kreminna
# Processing Record 19 of Set 10 | cabedelo
# Processing Record 20 of Set 10 | phuket
# Processing Record 21 of Set 10 | trincomalee
# Processing Record 22 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 10 | praia
# Processing Record 24 of Set 10 | dunedin
# Processing Record 25 of Set 10 | grindavik
# Processing Record 26 of Set 10 | aitape
# Processing Record 27 of Set 10 | sanming
# Processing Record 28 of Set 10 | neuquen
# Processing Record 29 of Set 10 | victor harbor
# Processing Record 30 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 31 of Set 10 | te anau
# Processing Record 32 of Set 10 | kiama
# Processing Record 33 of Set 10 | rorvik
# Processing Record 34 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 10 | lannion
# Processing Record 36 of Set 10 | porangatu
# Processing Record 37 of Set 10 | angoram
# Processing Record 38 of Set 10 | tupik
# Processing Record 39 of Set 10 | lagoa
# Processing Record 40 of Set 10 | vao
# Processing Record 41 of Set 10 | ceres
# Processing Record 42 of Set 10 | mumford
# Processing Record 43 of Set 10 | sept-iles
# Processing Record 44 of Set 10 | port moresby
# Processing Record 45 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 46 of Set 10 | inhambane
# Processing Record 47 of Set 10 | changping
# Processing Record 48 of Set 10 | bonavista
# Processing Record 49 of Set 10 | tuatapere
# Processing Record 0 of Set 11 | yarim
# Processing Record 1 of Set 11 | grand gaube
# Processing Record 2 of Set 11 | sosua
# Processing Record 3 of Set 11 | naron
# Processing Record 4 of Set 11 | monte alegre
# Processing Record 5 of Set 11 | nara
# Processing Record 6 of Set 11 | yantarnyy
# Processing Record 7 of Set 11 | tahta
# Processing Record 8 of Set 11 | karratha
# Processing Record 9 of Set 11 | saint-jean-port-joli
# Processing Record 10 of Set 11 | andenes
# Processing Record 11 of Set 11 | kudahuvadhoo
# Processing Record 12 of Set 11 | severodvinsk
# Processing Record 13 of Set 11 | riverton
# Processing Record 14 of Set 11 | constitucion
# Processing Record 15 of Set 11 | nchelenge
# Processing Record 16 of Set 11 | balikpapan
# Processing Record 17 of Set 11 | ayagoz
# Processing Record 18 of Set 11 | montepuez
# Processing Record 19 of Set 11 | charagua
# Processing Record 20 of Set 11 | murgab
# Processing Record 21 of Set 11 | san felipe
# Processing Record 22 of Set 11 | baruun-urt
# Processing Record 23 of Set 11 | lundazi
# Processing Record 24 of Set 11 | simitli
# Processing Record 25 of Set 11 | marsh harbour
# Processing Record 26 of Set 11 | fort nelson
# Processing Record 27 of Set 11 | buluang
# Processing Record 28 of Set 11 | dauphin
# Processing Record 29 of Set 11 | makokou
# Processing Record 30 of Set 11 | turayf
# Processing Record 31 of Set 11 | nieves
# Processing Record 32 of Set 11 | miranda
# Processing Record 33 of Set 11 | campoverde
# Processing Record 34 of Set 11 | soldotna
# Processing Record 35 of Set 11 | fukue
# Processing Record 36 of Set 11 | areosa
# Processing Record 37 of Set 11 | songjianghe
# Processing Record 38 of Set 11 | vanavara
# Processing Record 39 of Set 11 | nanakuli
# Processing Record 40 of Set 11 | pemangkat
# Processing Record 41 of Set 11 | yen bai
# Processing Record 42 of Set 11 | aklavik
# Processing Record 43 of Set 11 | alofi
# Processing Record 44 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 45 of Set 11 | hualmay
# Processing Record 46 of Set 11 | epe
# Processing Record 47 of Set 11 | pemba
# Processing Record 48 of Set 11 | kalisz
# Processing Record 49 of Set 11 | krasnokamensk
# Processing Record 0 of Set 12 | bubaque
# Processing Record 1 of Set 12 | shimoda
# Processing Record 2 of Set 12 | vagur
# Processing Record 3 of Set 12 | bronnoysund
# Processing Record 4 of Set 12 | innisfail
# Processing Record 5 of Set 12 | peniche
# Processing Record 6 of Set 12 | chany
# Processing Record 7 of Set 12 | iwanai
# Processing Record 8 of Set 12 | vila
# Processing Record 9 of Set 12 | kalmunai
# Processing Record 10 of Set 12 | esperance
# Processing Record 11 of Set 12 | redwater
# Processing Record 12 of Set 12 | viedma
# Processing Record 13 of Set 12 | bara
# Processing Record 14 of Set 12 | ixtapa
# Processing Record 15 of Set 12 | imeni zhelyabova
# Processing Record 16 of Set 12 | rio rancho
# Processing Record 17 of Set 12 | atar
# Processing Record 18 of Set 12 | eregli
# Processing Record 19 of Set 12 | college
# Processing Record 20 of Set 12 | pitiquito
# Processing Record 21 of Set 12 | ambon
# Processing Record 22 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 12 | madoc
# Processing Record 24 of Set 12 | zelenoborsk
# Processing Record 25 of Set 12 | dalbandin
# Processing Record 26 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 27 of Set 12 | haines junction
# Processing Record 28 of Set 12 | chala
# Processing Record 29 of Set 12 | bagdarin
# Processing Record 30 of Set 12 | westport
# Processing Record 31 of Set 12 | san jose
# Processing Record 32 of Set 12 | kualakapuas
# Processing Record 33 of Set 12 | naze
# Processing Record 34 of Set 12 | togur
# Processing Record 35 of Set 12 | piriyapatna
# Processing Record 36 of Set 12 | lar gerd
# City not found. Skipping...
# Processing Record 37 of Set 12 | riohacha
# Processing Record 38 of Set 12 | puerto del rosario
# Processing Record 39 of Set 12 | pietarsaari
# Processing Record 40 of Set 12 | ivanivka
# Processing Record 41 of Set 12 | yangshe
# Processing Record 42 of Set 12 | remedios
# Processing Record 43 of Set 12 | fairbanks
# Processing Record 44 of Set 12 | dingle
# Processing Record 45 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 46 of Set 12 | tomatlan
# Processing Record 47 of Set 12 | prainha
# Processing Record 48 of Set 12 | bow island
# Processing Record 49 of Set 12 | sawtell
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Export the city data into a .csv.
city_data_pd = pd.DataFrame(city_data)
city_data_pd.count()
# Out:
# City          550
# Lat           550
# Lng           550
# Max Temp      550
# Humidity      550
# Cloudiness    550
# Wind Speed    550
# Country       550
# Date          550
# dtype: int64

# %%
#Display the DataFrame
city_data_pd.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   bredasdorp -34.5322   20.0403     55.24        84           7        2.80
# 1       marawi   7.9986  124.2928     82.33        66          42        5.50
# 2  port alfred -33.5906   26.8910     57.18        77          52        3.00
# 3      ushuaia -54.8000  -68.3000     44.26        65          40       20.71
# 4    carnarvon -24.8667  113.6333     78.87        65           0       14.97
#
#   Country        Date
# 0      ZA  1651383162
# 1      PH  1651383162
# 2      ZA  1651383163
# 3      AR  1651383163
# 4      AU  1651383164

# %%
# Inspect the data and remove the cities where the humidity > 100%.
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.204281   19.557072   61.986000   70.300000   57.565455    8.063764
# std     33.322860   91.793415   18.776851   21.855191   38.708032    5.621145
# min    -54.800000 -175.200000   -6.790000    1.000000    0.000000    0.000000
# 25%     -8.064750  -62.584650   48.242500   60.000000   20.000000    3.475000
# 50%     22.530700   21.387700   64.530000   75.000000   65.000000    6.910000
# 75%     46.710750  103.596200   76.707500   87.000000   99.000000   11.520000
# max     78.218600  179.316700  103.600000  100.000000  100.000000   31.070000
#
#                Date
# count  5.500000e+02
# mean   1.651383e+09
# std    9.666391e+01
# min    1.651383e+09
# 25%    1.651383e+09
# 50%    1.651383e+09
# 75%    1.651383e+09
# max    1.651383e+09

# %%
 #  Get the indices of cities that have humidity over 100%.
dirty_city_data = city_data_pd[(city_data_pd["Humidity"] > 100)].index
                                  
dirty_city_data
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data_pd.drop(dirty_city_data, inplace=False)
clean_city_data.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   bredasdorp -34.5322   20.0403     55.24        84           7        2.80
# 1       marawi   7.9986  124.2928     82.33        66          42        5.50
# 2  port alfred -33.5906   26.8910     57.18        77          52        3.00
# 3      ushuaia -54.8000  -68.3000     44.26        65          40       20.71
# 4    carnarvon -24.8667  113.6333     78.87        65           0       14.97
#
#   Country        Date
# 0      ZA  1651383162
# 1      PH  1651383162
# 2      ZA  1651383163
# 3      AR  1651383163
# 4      AU  1651383164

# %%
# Extract relevant fields from the data frame
lats = clean_city_data["Lat"]
max_temps = clean_city_data["Max Temp"]
humidity = clean_city_data["Humidity"]
cloudiness = clean_city_data["Cloudiness"]
wind_speed = clean_city_data["Wind Speed"]

# Export the City_Data into a csv
clean_city_data.to_csv(output_data_file, index_label="City_ID")

# %%
#Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#Save the plotted figures as .pngs.

# %%
#Latitude vs. Temperature Plot
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

#save the figure
plt.savefig("output_data/Fig1.png")

#show plot
plt.show()

# %%
#Latitude vs. Humidity Plot
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

#Save the figure
plt.savefig("output_data/Fig2.png")

#Show plot
plt.show()

# %%
#Latitude vs. Cloudiness Plot
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
#Latitude vs. Wind Speed Plot
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
#Linear Regression
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Run regresson on southern hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(6,30))
# Out:
# The r-value is: 0.7723237427583033

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (-55, 90))
# Out:
# The r-value is: 0.46487192911608854

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))
# Out:
# The r-value is: 0.0010590117470176499

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (-50, 20))
# Out:
# The r-value is: 0.0012757186077888992

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (40,10))
# Out:
# The r-value is: 2.123947517863046e-06

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (-30,30))
# Out:
# The r-value is: 0.04835791370550677

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (40,25))
# Out:
# The r-value is: 0.018040569881517195

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (-50, 20))
# Out:
# The r-value is: 0.008456151512808414
